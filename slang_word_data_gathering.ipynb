# %% [markdown]
# This notebook had been ran on google colab due to the storage limit I have on my machine for installing pytorch library

# %%
# !pip install datasets

# %%
# !pip install fsspec==2024.9.0
# Out:
# ...
#   Using cached fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Using cached fsspec-2024.9.0-py3-none-any.whl (179 kB)
# ...
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# ...

# %%
# !pip install gcsfs==2024.9.0
# Out:
# ...
# WARNING: The candidate selected for download or install is a yanked version: 'gcsfs' candidate (version 2024.9.0 at https://files.pythonhosted.org/packages/46/87/165a7fc37498576b1622fe69b1915d60cf145bb5d7c4a2ee9943bad44040/gcsfs-2024.9.0-py2.py3-none-any.whl (from https://pypi.org/simple/gcsfs/) (requires-python:>=3.8))
# Reason for being yanked: requirements incorrect
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.6/177.6 kB 6.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.9.0
#     Uninstalling fsspec-2024.9.0:
#       Successfully uninstalled fsspec-2024.9.0
#   Attempting uninstall: gcsfs
#     Found existing installation: gcsfs 2024.10.0
#     Uninstalling gcsfs-2024.10.0:
#       Successfully uninstalled gcsfs-2024.10.0
# ...

# %%
# !pip install seacrowd
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.3/52.3 kB 2.3 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 54.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.3/92.3 kB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.6/220.6 kB 16.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 744.7/744.7 kB 37.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.3/100.3 kB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 7.5 MB/s eta 0:00:00
# ...

# %%
from datasets import load_dataset

# %%
# Load the Kamus Alay dataset
slangwords = load_dataset("SEACrowd/kamus_alay", trust_remote_code=True)
# Out:
# ...
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
import pandas as pd

# %%
slan_pd = pd.DataFrame(slangwords['train'])

# %%
slan_pd
# Out:
#           slang         formal  in_dictionary  \
# 0          woww            wow           True
# 1         aminn           amin           True
# 2           met        selamat           True
# 3        netaas        menetas           True
# 4       keberpa       keberapa          False
# ...         ...            ...            ...
# 15001  gataunya  enggak taunya          False
# 15002      gtau     enggak tau          False
# 15003     gatau     enggak tau          False
# 15004     fans2        fan-fan          False
# 15005   gaharus   enggak harus          False
#
#                                                  context  \
# 0                                                    wow
# 1      Selamat ulang tahun kakak tulus semoga panjang...
# 2      Met hari netaas kak!? Wish you all the best @t...
# 3      Met hari netaas kak!? Wish you all the best @t...
# 4                               Birthday yg keberpa kak?
# ...                                                  ...
# ...

# %%
slan_pd.to_csv('indo_slangwords.csv', index=False)

# %%
# !ls
# Out:
# indo_slangwords.csv  sample_data
